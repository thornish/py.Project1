# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
# ...

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df=df.replace({'s':np.NaN})
df=df.replace({'na':np.NaN})
df=df.replace({'0':np.NaN})

# %%
#Dropping the non structured values
dff =df.dropna(axis=1)

# %%
dff
# Out:
#        School DBN                     School Name School Level  Year  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8  2017
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8  2015
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8  2016
# 3          01M140          P.S. 140 Nathan Straus          K-8  2016
# 4          01M140          P.S. 140 Nathan Straus          K-8  2017
# ...           ...                             ...          ...   ...
# 212326     84X717            Icahn Charter School          K-8  2016
# 212327     84X717            Icahn Charter School          K-8  2016
# 212328     84X717            Icahn Charter School          K-8  2017
# 212329     84X717            Icahn Charter School          K-8  2017
# 212330     84X717            Icahn Charter School          K-8  2015
#
#         Total Tested
# 0                  4
# 1                 16
# 2                  9
# 3                  3
# 4                  2
# ...

# %%
#Unique School names
df1=df['School Name'].unique()

# %%
df1
# Out:
# array(['P.S. 034 Franklin D. Roosevelt', 'P.S. 140 Nathan Straus',
#        'P.S. 184m Shuang Wen', ..., 'Family Life Academy Charter School',
#        'Harriet Tubman Charter School', 'Icahn Charter School'],
#       dtype=object)

# %%
import matplotlib.pyplot as plot

# %% [markdown]
# # Lets find out the Schools with Top and Low count of Total tested

# %%
df2 = dff.groupby(['School Name'])['Total Tested'].count().sort_values(ascending = False)

# %%
df2 
# New Visions Charter High School for Advanced Math = Highest Tested
#Lowest tested: 
# Metropolitan Lighthouse Charter School                   5
#P.S./M.S. 20 P.O.George J. Werdann, III                  5
#P.S./M.S. 11X498 - VAN NEST ACADEMY                      5
#J.H.S. 166 George Gershwin                               5
#Explore Excel Charter School                             5
# Out:
# School Name
# New Visions Charter High School for Advanced Math     1337
# New Visions Charter High School for the Humanities    1031
# Francis Lewis High School                              490
# James Madison High School                              490
# Edward R. Murrow High School                           489
#                                                       ...
# Metropolitan Lighthouse Charter School                   5
# P.S./M.S. 20 P.O.George J. Werdann, III                  5
# P.S./M.S. 11X498 - VAN NEST ACADEMY                      5
# J.H.S. 166 George Gershwin                               5
# Explore Excel Charter School                             5
# Name: Total Tested, Length: 1012, dtype: int64

# %%
#Question: Form Datasets for 3 different schools

# %%
flhs = dff['School Name'] == 'Francis Lewis High School'

# %%
am = dff['School Name'] == 'New Visions Charter High School for Advanced Math'

# %%
h = dff['School Name'] == 'New Visions Charter High School for the Humanities'

# %%
df_am = dff[am]

# %%
df_h = dff[h]

# %%
df_am
# Out:
#        School DBN                                        School Name  \
# 18193      84K738  New Visions Charter High School for Advanced Math
# 18194      84K738  New Visions Charter High School for Advanced Math
# 18195      84K738  New Visions Charter High School for Advanced Math
# 18196      84K738  New Visions Charter High School for Advanced Math
# 18197      84K738  New Visions Charter High School for Advanced Math
# ...           ...                                                ...
# 211965     84X539  New Visions Charter High School for Advanced Math
# 211966     84X539  New Visions Charter High School for Advanced Math
# 211967     84X539  New Visions Charter High School for Advanced Math
# 211968     84X539  New Visions Charter High School for Advanced Math
# 211969     84X539  New Visions Charter High School for Advanced Math
#
#        School Level  Year  Total Tested
# 18193   High school  2015            70
# 18194   High school  2016            24
# ...

# %%
df_h
# Out:
#        School DBN                                        School Name  \
# 18220      84K739  New Visions Charter High School for the Humani...
# 18221      84K739  New Visions Charter High School for the Humani...
# 18222      84K739  New Visions Charter High School for the Humani...
# 18223      84K739  New Visions Charter High School for the Humani...
# 18224      84K739  New Visions Charter High School for the Humani...
# ...           ...                                                ...
# 212091     84X553  New Visions Charter High School for the Humani...
# 212092     84X553  New Visions Charter High School for the Humani...
# 212093     84X553  New Visions Charter High School for the Humani...
# 212094     84X553  New Visions Charter High School for the Humani...
# 212095     84X553  New Visions Charter High School for the Humani...
#
#        School Level  Year  Total Tested
# 18220   High school  2015            39
# 18221   High school  2016            12
# ...

# %%
#Try plotting Two Schools and Total tested in a Year
ax=df_am.plot()
df_h.plot(ax=ax)
#Plot between 'New Visions Charter High School for the Humanities' and 'New Visions Charter
#High School for Advanced Math'

# %%
ax=df_h.plot()
df_am.plot(ax=ax)

# %%
df_flhs = df[flhs]
df_flhs
# Out:
#        School DBN                School Name School Level  \
# 14549      26Q430  Francis Lewis High School  High school
# 14550      26Q430  Francis Lewis High School  High school
# 14551      26Q430  Francis Lewis High School  High school
# 14552      26Q430  Francis Lewis High School  High school
# 14553      26Q430  Francis Lewis High School  High school
# ...           ...                        ...          ...
# 194228     26Q430  Francis Lewis High School  High school
# 194229     26Q430  Francis Lewis High School  High school
# 194230     26Q430  Francis Lewis High School  High school
# 194231     26Q430  Francis Lewis High School  High school
# 194232     26Q430  Francis Lewis High School  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 14549         Algebra2/Trigonometry  2015           845       77.8
# 14550         Algebra2/Trigonometry  2016           889       76.7
# ...

# %%
df_flhs.plot(kind = "hist", x ='Year', y= 'Total Tested')
#df_flhs.groupby(['Year'])['Total Tested'].count().plot(kind="bar")

# %%
#Descriptive Analysis for 1 School's data
df_flhs.describe()
# Out:
#               Year  Total Tested
# count   490.000000    490.000000
# mean   2015.942857    304.683673
# std       0.794150    295.056668
# min    2015.000000      1.000000
# 25%    2015.000000     61.250000
# 50%    2016.000000    203.500000
# 75%    2017.000000    490.750000
# max    2017.000000   1264.000000

# %%
df_ms01 = dff[dff['School DBN'].str.contains('01M')]

# %%
df_ms01
# Out:
#        School DBN                     School Name  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt
# 1          01M034  P.S. 034 Franklin D. Roosevelt
# 2          01M034  P.S. 034 Franklin D. Roosevelt
# 3          01M140          P.S. 140 Nathan Straus
# 4          01M140          P.S. 140 Nathan Straus
# ...           ...                             ...
# 140914     01M839   Tompkins Square Middle School
# 140915     01M839   Tompkins Square Middle School
# 140916     01M839   Tompkins Square Middle School
# 140917     01M839   Tompkins Square Middle School
# 140918     01M839   Tompkins Square Middle School
#
#                            School Level  Year  Total Tested
# 0                                   K-8  2017             4
# 1                                   K-8  2015            16
# 2                                   K-8  2016             9
# 3                                   K-8  2016             3
# ...

# %% [markdown]
# # Plots for different schools and their respective Total tested and Years

# %%
df_ms01.groupby(['School Name'])['Total Tested'].count().sort_values(ascending = False).plot(kind="bar")

# %%
df_xs84 = dff[dff['School DBN'].str.contains('84X')]
# Dataset for Schools in the Bronx Borough and district 84
df_xs84
# Out:
#        School DBN                       School Name  \
# 18528      84X703  Bronx Preparatory Charter School
# 18968      84X177          Mott Hall Charter School
# 18969      84X177          Mott Hall Charter School
# 18970      84X177          Mott Hall Charter School
# 18971      84X177          Mott Hall Charter School
# ...           ...                               ...
# 212326     84X717              Icahn Charter School
# 212327     84X717              Icahn Charter School
# 212328     84X717              Icahn Charter School
# 212329     84X717              Icahn Charter School
# 212330     84X717              Icahn Charter School
#
#                            School Level  Year  Total Tested
# 18528                  Secondary School  2017             3
# 18968   Junior High-Intermediate-Middle  2015            14
# 18969   Junior High-Intermediate-Middle  2015            10
# 18970   Junior High-Intermediate-Middle  2017             5
# ...

# %%
df_xs84.groupby(['School Name'])['Total Tested'].count().sort_values(ascending = False).plot(kind="bar")
